# %% [markdown]
# # Second Stage
#
# In this stage, mainly conducted LDA (Latent Dirichlet Allocation) study on a sample size of the original data. As we used t-SNE to reduce feature dimension, sample size is limited due to the processing time. Maybe other method should be considered if the data size is big or should break down data into chunks for easier processing.

# %%
import warnings
import lda
import logging
import dill 
import os
import pandas as pd
import numpy as np
import bokeh.plotting as bp
import random

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook
from collections import Counter

warnings.filterwarnings("ignore", category=DeprecationWarning)
logging.getLogger("lda").setLevel(logging.WARNING)
code_dir = os.getcwd()
data_dir = code_dir.replace('code', 'data')

# %%
sub_body = dill.load(open(data_dir+'/#patent_title_lemma.pkd', 'rb'))

tokens = sub_body['title_lemma'].tolist()
titles = []
for token in tokens:
    titles.append(' '.join(token))

sub_body['title_lemma'] = titles
sub_body = sub_body.drop_duplicates(subset='title_lemma')
sub_body = sub_body.dropna(subset=['sector'])
sub_body.shape
# Out:
# (395873, 8)

# %%
c = Counter(sub_body['sector'].tolist())
c.most_common()
# Out:
# [('Information Technology', 256658),
#  ('Industrials', 62841),
#  ('Telecom Services', 22903),
#  ('Financials', 14141),
#  ('Healthcare', 13445),
#  ('Consumer Cyclicals', 9033),
#  ('Energy', 7300),
#  ('Raw & Intermediate Materials', 6459),
#  ('Consumer Staples', 2265),
#  ('Utilities', 394)]

# %%
sample = sub_body.sample(3000)
sample.head()
# Out:
#             exec_dt                    or_name  \
# 162630   2002-04-09               HO, JIN-MENG
# 31916    2001-01-04  MCCLOSKEY, PATRICK JOSEPH
# 249883   2001-05-02            BATES, CARY LEE
# 1155297  2010-06-17           PAEK, TIMOTHY S.
# 1680815  2008-10-27         ANDERSEN, DAVID M.
#
#                                                      title  \
# 162630   [signaling, parameterized, quality, service, (...
# 31916    [optimization, polycarbonate, preparation, tra...
# 249883   [operation, control, system, ensuring, availab...
# 1155297                    [real-time, typing, assistance]
# 1680815                                 [local, collector]
#
#                                      ee_name_matched ticker  \
# 162630                TEXAS INSTRUMENTS INCORPORATED    TXN
# 31916                       GENERAL ELECTRIC COMPANY     GE
# 249883   INTERNATIONAL BUSINESS MACHINES CORPORATION    IBM
# 1155297                        MICROSOFT CORPORATION   MSFT
# 1680815                  BANK OF AMERICA CORPORATION    BAC
#
#                          sector  \
# 162630   Information Technology
# 31916               Industrials
# 249883   Information Technology
# 1155297  Information Technology
# 1680815              Financials
#
#                                                 title_stem  \
# 162630   [signal, parameter, qualiti, servic, qo, support]
# 31916            [optim, polycarbon, prepar, transesterif]
# 249883   [oper, control, system, ensur, avail, purchas,...
# 1155297                           [real-tim, type, assist]
# 1680815                                 [local, collector]
#
#                                                title_lemma
# 162630   signaling parameterized quality service qos su...
# 31916    optimization polycarbonate preparation transes...
# 249883   operation control system ensuring availability...
# 1155297                        real-time typing assistance
# 1680815                                    local collector

# %%
title_list = sample['title_lemma'].tolist()
title_list
# Out:
# ['signaling parameterized quality service qos support',
#  'optimization polycarbonate preparation transesterification',
#  'operation control system ensuring availability purchasable item networked machine',
#  'real-time typing assistance',
#  'local collector',
#  'radiation curable silicon containing polyacrylate hardcoat composition method making use',
#  'input/output core design method manufacture therefor',
#  'pseudo wire mobility management',
#  'technique introduce advanced functional behavior database management system without introducing new data type',
#  'microdisplay eye gaze detection',
#  'multi-space distribution pattern recognition based mixed continuous discrete observation',
#  'method system apparatus measuring temperature cold junction compensation',
#  'system method touch screen control ultrasound system',
#  'method apparatus binding subscriber authentication device authentication communication system',
#  'intelligent migration device different hardware software configuration',
#  'apparatus method storing initializing branch prediction selective information transfer',
#  'method apparatus monitoring electronic apparatus activity',
#  'hierarchical mobile ad-hoc network method route error recovery therein',
#  'inkjet ink comprising modified pigment attached polymeric group',
#  'desktop environment color alert system printing device',
#  'rotor blade section method assembling rotor blade wind turbine',
#  'gate-induced strain mo performance improvement',
#  'securely publishing user profile information across public insecure infrastructure',
#  'radio frequency heating fork',
#  'methylated methylolated melamine composition',
#  'optimizing latest user defined class loader',
#  'automatic identification modifier term title string',
#  'system method computer readable medium avoiding network address collision',
#  'hierarchical feedback channel state information wireless communication',
#  'isolator depending component electrostatic field sprayer boom',
#  'structural repair optical witness method monitoring repair performance',
#  'device system method memory allocation',
#  'method facilitating user input handheld electronic device employing text disambiguation function',
#  'facilitating efficeint free in-plane rotation landmark tracking image computing device',
#  'cache management asynchronous memory move operation',
#  'system method cache coherency multiprocessor system',
#  'technique performing arbitrary width integer arithmetic operation using fixed width element',
#  'method modifying copy protected video signal negative amplitude pulse',
#  'showing correcting irregularity schedule',
#  'liquid-cooled grounded heatsink diode rectifier system generator excitation system',
#  'automatic reuse user-specified content query',
#  'method apparatus redefining group related object relational database system',
#  'photovoltaic device electroplated metal grid',
#  'digital system adjusting delay circuit board',
#  'method making electrical circuit',
#  'system method providing black white image compression',
#  'link chain verification validation methodology digital device',
#  'method system integrated simulation tool using business pattern script',
#  'lpar creation repair automated error recovery',
#  'dynamic profile access control',
#  'on-demand point-of-sale personalized product-related information',
#  'method apparatus generating massive interrupt random access memory ram',
#  'light emitting diode improved efficiency',
#  'power electronic module packaging',
#  'firewall methodology use within virtual environment',
#  'damper element spring vehicle pedal assembly incorporating',
#  'second order active filter',
#  'method system define multiple metrology criterion defect screening electrical connection',
#  'hydrogel wound dressing product',
#  'live partition mobility using ordered memory migration',
#  'remote interaction wireless device resident diagnostic interface across wireless network',
#  'siebel spf template file update utility',
#  'measurement expert system method generating high-performance measurement software driver',
#  'raster vector map conversion',
#  'search personalization using identifier authentication state',
#  'method apparatus providing simple secure management remote server',
#  'method apparatus generating image using color field sequential display',
#  'method apparatus rule-based random irritator model stimulus',
#  'advertisement system using retailer inventory',
#  'magnetic device magnetic trip unit',
#  'method target generation multilevel hierarchical circuit design',
#  'insitu dry cleaning process poly gate etch',
#  'method planning movement train using route protection',
#  'automated malware signature generation',
#  'field shield isolated eprom',
#  'system method using pick place apparatus',
#  'system method providing low battery notification mobile device',
#  'system method program product managing privilege level computer system',
#  'method apparatus phased array acoustic well logging',
#  'symbolic execution object oriented program axiomatic summary',
#  'system method performing crawl search index search',
#  'oled improved luminance stability',
#  'multiple independent measurement event multiple measurement setup entered single time',
#  'method electronically generating spoken message',
#  'optimal magnetization non-magnetized permanent magnet segment electrical machine',
#  'system method composing image fragment',
#  'navigation wristwear',
#  'system method routing emergency service call fixed wireless terminal',
#  'method apparatus system delivery wide range turbine fuel combustion',
#  'convertible back bar',
#  'method system system migration',
#  'use 1:1 protection state machine load sharing alternative protection scheme',
#  'method system updating electronic mail address book',
#  'context specific speaker adaptation user interface',
#  'composition treatment inflammation pain using combination cox-2 selective inhibitor ltb4 receptor antagonist',
#  'apparatus system method cutting creasing medium',
#  'finfet device formation',
#  'xml-based representation mobile process calculus',
#  'method system preprocessing data block header access data data storage system',
#  'dynamically optimizing memory allocation across virtual machine',
#  'method apparatus inferring read status instant message',
#  'master key encryption function transmitter-receiver pairing countermeasure thwart key recovery attack',
#  'inkjet printing apparatus',
#  'software development automated analytics',
#  'method system apparatus computer-readable medium tracking referral product sell-through',
#  'investigation device method',
#  'rate-matched cell identification modification replacement insertion test measurement atm network virtual connection',
#  'correction dc offset data bus structure receiver',
#  'communication device providing automatically initiated outgoing communication incoming communication',
#  'recombinant mono poly antigen detect cytomegalovirus- specific igm human serum enzyme immunoassay',
#  'direct decimal number tripling binary coded adder',
#  'composite engine intake module integrated component handling gaseous fluid',
#  'method transmission time division multiplexed pilot symbol aid channel estimation time synchronization agc bootstrapping multicast wireless system',
#  'edge wheel assembly substrate processing brush box',
#  'ram air turbine integrated heat exchanger',
#  'method carbon black production using preheated feedstock apparatus',
#  'microprogrammed digital data processing system employing multi-phase subroutine control concurrently executing task',
#  'system method static analysis using fault path',
#  'input device transmitter path error diagnosis',
#  'dual cross-media relevance model image annotation',
#  'method apparatus minimizing inconsistency data source web content distribution system',
#  'separation membrane formed perforated graphene method use thereof',
#  'user interface gestural control',
#  'method apparatus administration database partition',
#  'acoustic noise reduction system disk drive',
#  'system method mobile power conditioning platform',
#  'reflector lamp',
#  'extending interactive input via sensor fusion',
#  'on-board aircraft system method achieving maintaining spacing',
#  'method apparatus resuming memory operation low latency wake-up low power state',
#  'apparatus method supporting workpiece plasma processing',
#  'in-situ nano-interconnected circuit device method making',
#  'system method producing dry toner associated selected gloss level',
#  'heterogeneous evolutionary self-formatting internet protocol',
#  'electron beam position reference system',
#  'head stack assembly disk drive unitary molded plastic e-block',
#  'method system capturing video personal computer',
#  'head actuator spring loaded split nut',
#  'non-linear dielectric used electrical insulation rotating electrical machinery',
#  'method apparatus graphically marking instruction instrumentation hardware assistance',
#  'rendering object graphical rendering device clipped image',
#  'dissymmetric coil antenna facilitate near field coupling',
#  'system method computer program product implementing spatially varying unsharp mask noise reduction filter',
#  'method system defining redundancy window around particular column memory array',
#  'pinsetter masking unit',
#  "method system forcing e-mail address blind carbon copy `` bcc '' enforce privacy",
#  'process enhanced lithographic imaging',
#  'wireless video streaming quality management bandwidth constrained cellular network',
#  'method system apparatus delivering web content',
#  'method translate udps using gate primitive',
#  'dynamically adaptable impedance matching circuitry electro-optical load driving source',
#  'system method control multiple engine marine vessel',
#  'system method improved detection signal',
#  'integrated packaged magnetic component',
#  'method apparatus customizing model entity presentation based presentation policy',
#  'system method use improving operation utility equipment',
#  'thermoplastic composition method making article formed therefrom',
#  'processor data processing system method initializing memory block initialization value without cache first obtaining data valid copy',
#  'transport block size determination',
#  'efficient management hierarchically-linked data storage space',
#  'accelerated visualization surface light field',
#  'parallel remote administration mirrored alternate volume group distributed data processing system',
#  'method changing removable bearing wind turbine generator',
#  'wireless device swap',
#  'filter retainer turbine engine',
#  'end-to-end deployment validation communication system',
#  'emi/rfi shielding electronic assembly',
#  'system method exonerating untrusted software component',
#  'method structure identifying lead-free solder',
#  'advanced decision logic transit acceptance',
#  'method wind turbine placement wind power plant',
#  'dynamically balancing bus bandwidth',
#  'method system steam quality monitoring',
#  'optical intensity modifier',
#  'connection slider 3d object allow easy user manipulation viewing object',
#  'storage array boot configuration',
#  'terminating enhanced television broadcast',
#  'transmitting data general packet radio service wireless network',
#  'dual layer gate dielectric non-silicon semiconductor device',
#  'signal processing method use optical navigation system',
#  'adjusting log size static logical volume',
#  'system method calibration optical module',
#  'apparatus method locate failed device data storage system',
#  'high melting point copper-gold-tin brazing alloy chip carrier',
#  'method apparatus implementing connection circuit',
#  'image compression synthesis video effect',
#  'organometallic hydrocarbon additive use aluminum back solar cell contact',
#  'system method name-lookup local area network data communication system',
#  'technique forming contact hole silicon layer substrate',
#  'transferring data stacked memory',
#  'zwitterionic sulfone polymer blend hollow-fiber membrane',
#  'correcting error memory device',
#  'method apparatus estimating cell interference noise cdma packet data channel',
#  'technique utilizing step size adaptation differential beamforming wireless network',
#  'enqueuing apparatus asynchronous transfer mode atm virtual circuit merging',
#  'smooth layout animation continuous non-continuous property',
#  'emulsion comprising ternary surfactant blend cationic anionic bridging surfactant oil water method preparing',
#  'script compliance quality assurance based speech recognition duration interaction',
#  'method apparatus negative resistance wireless power transfer',
#  'self-tuning adaptive bandwidth regulator',
#  'method preparing pyrimidine derivative useful protein kinase inhibitor',
#  'tti bundling random access procedure',
#  'determining bidder-aware value configurable auction parameter',
#  'system apparatus frequency translation magnetic resonance mr signal',
#  'high-performance adder',
#  'monitoring access thread multiple memory controller selecting thread processor thread based monitoring',
#  'processing variable length device command word control unit i/o processing system',
#  'writing multiple level phase change memory',
#  'long term calibration sensor assembly glass-ceramic cooktop appliance',
#  'unaddressed device communication within mpls network',
#  'nutritive substance delivery container',
#  'hierarchical distributed object storage system',
#  'method system calibrate characterize image capture device using calibrated display known colorimetric property',
#  'method apparatus optimal critical netlist area selection',
#  'process removing holefill residue metallic surface electronic substrate',
#  'detecting underground object',
#  'system ppu/gpu architecture',
#  'stack filter one stage per bit',
#  'method apparatus providing alternative power source graphic card',
#  'policy application across multiple node',
#  'chip monitor',
#  'dma port sharing bandwidth balancing logic',
#  'bed foundation',
#  'password-authenticated association based public key scrambling',
#  'status hub used autonomic application server',
#  'incremental redundancy using two stage rate matching automatic repeat request obtain high speed transmission',
#  'gas engine driven heat pump system integrated heat recovery energy saving subsystem',
#  'byte level granularity buffer overflow detection memory corruption detection architecture',
#  'method apparatus composite configuration item management configuration management database',
#  'electric motor phase control system',
#  'fabrication localized soi localized thick box using selective epitaxy bulk semiconductor substrate photonics device integration',
#  'dip tube anchor assembly related container',
#  'implementing second computer system interface first computer system',
#  'system method estimating ink usage inkjet printer',
#  'circuit method controlling liquid crystal segment display',
#  'ballast inflatable water slide',
#  'method apparatus utilizing social usage learned multi-user feedback improve resource identity signifier mapping',
#  'processing information management plasma processing tool',
#  'security certificate management',
#  'article continuous grain size radial gradient method making',
#  'active efficient monitoring graphical user interface',
#  'vlsi layout design job scheduling method',
#  'method system motivate tuning transmission channel time period',
#  'transaction info bypass node coupled interconnect fabric',
#  'integrated circuit package strip support assembly',
#  'tensionable threaded rebar bolt',
#  'method apparatus constrained system attribute allocation uncertain usage profile',
#  'continuous medium stream control',
#  'turbine fuel delivery apparatus system',
#  'circuit method driving resonant actuator',
#  'power calibration voltage standing wave ratio change frequency sweep',
#  'managing data retention database operated database management system',
#  'lock mechanism reduce waiting thread access shared resource selectively granting access thread enqueued highest priority thread',
#  'transmission-gate based flip-flop',
#  'high-speed feedthrough stair-like shape transmission line formed multi-layer substrate',
#  'system method increasing roll offset operating range spacecraft',
#  'accelerating shortest path problem',
#  'apparatus method provide current location information service network',
#  'digital x-ray detector increased dynamic range',
#  'harsh environment temperature sensing system method',
#  'switching mode regulator sfp ethernet adaptor',
#  'system method computer-readable medium costing user-defined function method database management system',
#  'antifuse structure integrated heating element',
#  'method making catheter',
#  'load current control circuitry power supply driving common load providing uniform temperature distribution',
#  'computer-implemented system method offering commercial parking reservation',
#  'technique automatic management file system encryption driver',
#  'coordinating update replicated data',
#  'control method communication relay system',
#  'decorrelation low discrepancy sequence progressive rendering',
#  'detecting managing change business data integration solution',
#  'trusted e-mail communication multi-tenant environment',
#  'authoring arbitrary xml document using dhtml xslt',
#  'hot-read data aggregation code selection',
#  'dynamic security question compromise checking based incoming social network posting',
#  'cover integrated lens integrated chip optical sensor',
#  'post passivation structure semiconductor chip wafer',
#  'multiplexing control data varying power offset sc-fdma system',
#  'microfluidic cartridge',
#  'organopolysiloxane coating composition',
#  'automated material distribution control stretch blow molded article',
#  'signal characteristic-based leading edge detection',
#  'interpretation real time casing image rtci data 3d tubular deformation image',
#  'flat heat exchanger tube',
#  'managing power consumption performance computing system',
#  'optimal performance power management two dependent actuator',
#  'ripple-current reduction scheme ac converter',
#  'high voltage lateral semiconductor device',
#  'method apparatus network cognizant uplink transmission irat handover',
#  'transceiver based loop back initiation',
#  'method structure reduce latch-up using edge implant',
#  'detection denial service attack internet server',
#  'system apparatus applying label cable conduit',
#  'optical path structure open path emission sensing particulate matter lubricating oil consumption absorption methodology',
#  'audio start service ad-hoc meeting',
#  'compare swap store facility external serialization',
#  'shared driver multi-core processor',
#  'data cache block deallocate request',
#  'system method state management networked system',
#  'method improving performance automated test system',
#  'model predicting perception item interest',
#  'cleanability assessment sublimate lithography material',
#  'method system product programming simultaneous multi-threaded processor environment',
#  'server blade chassis airflow bypass damper engaging upon blade removal',
#  'system computer program inserting record database',
#  'electronic device method scheduling calendar event',
#  'allocating access multiple radio access technology via multi-mode access point',
#  'variably changing nip feeding speed maintain optimal sheet buckle',
#  'method hollow selection feedback',
#  'method apparatus system accessing application across plurality computer',
#  'system method transformer failure detection control',
#  'cmos hybrid substrate different crystal orientation using silicon-to-silicon direct wafer bonding',
#  'control dopant diffusion polysilicon emitter bipolar integrated circuit',
#  'contextual text adaptation',
#  'coupon effectiveness index',
#  'situ proximity gap monitor lithography',
#  'heterogeneous building block scalability',
#  'method apparatus beat elimination rf signal modulated pulsed signal similar frequency',
#  'user-configurable on-chip program memory system',
#  'silicon-on-sapphire integrated circuit method making',
#  'control device blower air conditioner module motor vehicle',
#  'nuclear magnetic resonance measurement well logging using optimized rephasing pulse sequence',
#  'method system efficiently multiplying signed unsigned variable width operand',
#  'method mechanical data storage device operation control',
#  'antireflective coating',
#  'computer display like',
#  'parallel tree based prediction',
#  'method system responding handover event positioning session',
#  'caching lookup based upon tcp traffic flow characteristic',
#  'electric motor ice protection',
#  'resolution group membership resource',
#  'system method estimating time engine event',
#  'serial optical interconnect bus logic card like',
#  'method system real time measurement data adjudication service level evaluation',
#  'bioactive material aneurysm repair',
#  'switched capacitor integrator share capacitor input signal reference signal',
#  'sample collection using catheter expandable member',
#  'apparatus method modem detecting call waiting signal',
#  'method apparatus predicting channel quality indicator communication system',
#  'autonomic reclamation processing tape',
#  'structured displaying visual element',
#  'voice interface social networking service',
#  'turbine bucket platform shaping gas temperature control related method',
#  'three stage hybrid stack model',
#  'polymer stabilized molecular whole transporting material organic electroluminescence display',
#  'right management cloud',
#  'one mask high density capacitor integrated circuit',
#  'technique forming chalcogenide thin film using additive liquid-based chalcogenide precursor',
#  'system method assembling rotor lock assembly use wind turbine',
#  'platform posture policy information exchange method apparatus',
#  'modular chassis providing scalable mechanical electrical environmental functionality microtca advanced tca board',
#  'transferring control common gain element wireless device supporting multiple protocol',
#  'one-to-many disk imaging transfer network',
#  'state breakout appliance mobile data network',
#  'method data processing system per-chip thread queuing multi-processor system',
#  'foam cushioning panel packaging purpose',
#  'image scaling using cubic filter',
#  'access request authentication authorization information generation',
#  'hand-held pneumatic vacuum',
#  'scheduling multithreaded programming instruction based dependency graph',
#  'paper height measure appaaratus medium tray linear sensor switch',
#  'anisotropic nitride etch process high selectivity oxide photoresist layer damascene etch scheme',
#  'axial compressor blade retention',
#  'handicap accessible removable control panel',
#  'filter signal tap temporally spaced fractional symbol interval',
#  'method making circuitized substrate resultant circuitized substrate',
#  'tailoring via-hole sidewall slope',
#  'gas turbine engine structural frame multi-yoke attachment strut outer casing',
#  'method apparatus directory-based coherence distributed directory management utilizing prefetch cache',
#  'information management information display system',
#  'inter-device session connectivity enhancement',
#  'reduced stress high voltage word line driver',
#  'non-collinear light engine color imaging system',
#  'dynamic computation line segment arrangement using finite precision arithmetic use processor controlled system',
#  'gaseous ozone o3 treatment solar cell fabrication',
#  'parallel processing pixel data',
#  'airway seal apparatus method refrigerator apparatus using seal',
#  'method system dynamically controlling display refresh rate',
#  'apparatus method removing bonded lid substrate',
#  'rigid magnetic coating composition thermosetting binder hard file',
#  'marine propeller',
#  'symmetrical hexagonal-based ball grid array pattern',
#  'substituted pyrrolo 2,3-d pyrimidine inhibitor protein kinase',
#  'method sensing presence human body part within region machine tool',
#  'fault tolerant usb method apparatus',
#  'method apparatus managing image data presentation display',
#  'use ethylene glycol corrosion inhibitor cleaning metal chemical mechanical polishing',
#  'embedded electronic packaging associated method',
#  'method system computer program product encryption key management secure processor vault',
#  'semantics mapping different object hierarchy',
#  'temperature-based thread scheduling',
#  'tube port related container system',
#  'lockless scheduling decreasing chunk loop parallel program',
#  'memory device reduced operating voltage dielectric stack',
#  'selectable decoupling capacitor integrated circuit method use',
#  'type restriction mapping partial materialization',
#  'method fast incremental calculation impact coupled noise timing',
#  'recoup turbojet engine',
#  'formation recessed polysilicon plug using chemical-mechanical-polishing cmp selective oxidation',
#  'ultrasonic ranging control system industrial robot',
#  'keyboard dome overlay structure',
#  'pump system method thereof',
#  'gas detection system incorporating fiber gas sensor fiber bragg grating',
#  'heat exchanger thermoacoustic heat pump',
#  'characterizing dimension structure via scanning probe microscopy',
#  'multiband antenna apparatus method',
#  'web site implementation mapping expression evaluation',
#  'executing state machine processing module executive processing module',
#  'process fabricating two different gate dielectric thickness using polysilicon mask chemical mechanical polishing cmp planarization',
#  'data virtualization across heterogeneous format',
#  'electrostatic discharge compliant patterned adhesive tape',
#  'mass-based sensing charging knee active control charger setting',
#  'device method indicating initial router path packet switching network',
#  'method system improved modeling language profile',
#  'method system controlling information flow producer multiple buffer high frequency digital system',
#  'partition transparent correctable error handling logically partitioned computer system',
#  'method apparatus providing medium player copy protection signal negates circumvention device provides improved playability',
#  'method apparatus implementing wildcard pattern spellchecking operation',
#  'video multiviewer system using direct memory access dma register block ram',
#  'calibrating optical disk laser using minimal amount write-once data storage space',
#  'embedded bus emulation',
#  'optical reflector reducing radiation heat transfer hot engine part',
#  'method apparatus determining adjacency wireless device po terminal',
#  'determining combination odor produce target olfactory pleasantness',
#  'alignment mark salicided spacers bitlines alignment signal improvement',
#  'system method airborne launch recovery aircraft',
#  'contact bar modifying stress semiconductor device related method',
#  'derivation feedback transmit steering matrix',
#  'self-diagnostic flame rectification sensing circuit method therefor',
#  'apparatus dissipating electromagnetic wave',
#  'apparatus system method limiting latency',
#  'device system method detecting erroneous packet',
#  'spatial binning particle gpu',
#  'dishwasher rack adjustable shelf',
#  'channel state information feedback frame format feedback rule high throughput wireless system',
#  'low dispersion interleaver',
#  'method generating electrochemically activated cleaning liquid',
#  'enhanced browser navigation',
#  'passive radio frequency device monitoring wear component',
#  'frequency bin method initial carrier frequency acquisition',
#  'method device isolating positioning single nucleic acid molecule',
#  'scene change detection using quantization scale factor rate control',
#  'dynamic intrusion detection computer system',
#  'method fabrication mimcap resistor level',
#  'baseline indexed versioned data',
#  'numerical stall analysis cpu performance',
#  'input/output adapter card plug play compliant mode assigned resource mode',
#  'diketopyrrolopyrrole-based derivative thin film transistor',
#  'inter-layer communication receipt confirmation releasing retransmission buffer content',
#  'sub-sea chemical injection metering valve',
#  'machine data management system using removable controller',
#  'technique reduced pixel shading',
#  'device method control channel decoding preamble skip reduce decoding time',
#  'system method allowing user ensure action taken document applied recent electronic correspondence',
#  'providing high data rate dsl system connected multiple pair wire',
#  'using pulse density modulation controlling dimmable electronic lighting ballast',
#  'antenna support bracket',
#  'transparent encryption/decryption gateway cloud storage service',
#  'method acoustic echo cancellation full-duplex hand free audio conferencing spatial directivity',
#  'method system detecting breathing tube occlusion',
#  'system method parallel processing imaging information',
#  'shuffling video privacy protection',
#  'method system ranking image using semantic aesthetic model',
#  'system method enhanced television interaction',
#  'method write data information storage retrieval system',
#  'non-common capping layer organic device',
#  'adaptive bit loading low density parity check forward error correction',
#  'dual source side polysilicon select gate structure utilizing single tunnel oxide nand array flash memory',
#  'contextual connection recommendation social network',
#  'iterative filter framework medical image',
#  'dynamic cooling computing system',
#  'video-annotation entry display apparatus',
#  'device element allocation manager method multi-library system multiple host connection',
#  'phase change ink imaging component polymer hybrid layer',
#  'color icon portion display screen',
#  'resource arbitration shared-write access via persistent reservation',
#  'method apparatus n+1 packet level mesh protection',
#  'apparatus method improved permute instruction',
#  'querying database client utilizing email message',
#  'chaining animation',
#  'measurement management technology platform',
#  'using protection information metadata field storing configuration information',
#  'portable device mobile phone double hinge torsion bar',
#  'air gap based low dielectric constant interconnect structure method making',
#  'address transition detection sensing interface flash memory multi-bit cell',
#  'reprinting',
#  'method system automatically transforming provider offering customer specific service environment definition executable resource management system',
#  'multilayer stent',
#  'optical pulse source',
#  'flap array fluidic electrical control',
#  'secure network attached storage device using cryptographic setting',
#  'apparatus method efficient memory allocation',
#  'method forming metal interconnection line semiconductor device',
#  'circuit linear conversion current voltage',
#  'printer driver apparatus method',
#  'defect detection integer',
#  'optical device optical connector assembly optical connecting method',
#  'managing family information',
#  'system method selective association',
#  'carton bottom sealer',
#  'adaptive noise gate method',
#  'method system non-invasive blood pressure determination',
#  'system method adaptive control robotic device',
#  'method apparatus precision cutting fiber',
#  'method apparatus locating gps equipped wireless device operating analog mode',
#  'remote firmware recovery',
#  'repair method low noise metal line thin film imager device',
#  'remote visual inspection system method',
#  'attachment fitting wall flexible structure',
#  'enhancing reliability transaction execution using transaction digest',
#  'method apparatus off-load processing message stream',
#  'sensorless field-oriented control foc without current sampling motor',
#  'polishing head removable subcarrier',
#  'creating presentation document',
#  'processing algebraic expression keyed data set',
#  'analyzing reporting business objective multi-component information technology solution',
#  'multi-piece wind turbine rotor blade wind turbine incorporating',
#  'forging die process',
#  'engine control strategy marine propulsion system improving shifting',
#  'wear sleeve',
#  'conditional adaptation linear filter system nonlinearity',
#  'automating trust establishment trust management identity federation',
#  'polynucleotides encoding molecule associated cell proliferation',
#  'dual operational brake light control trailer',
#  'affinity virtual processor dispatching',
#  'method apparatus command queue ordering sort time reduction algorithm',
#  'praseodymium-rich iron-boron-rare earth composition permanent magnet produced therefrom method making',
#  'system method reduce temperature induced drift effect liquid lens',
#  'enhanced recordation device rail car inspection',
#  'remote management simultaneous display multimedia content display device',
#  'propagate delta information enterprise information system',
#  'method system generating quality enhancement project report',
#  'system method classifying security event targeted attack',
#  'distributed multicast caching technique',
#  'unified communication aware network',
#  'fluid mixing system tiltable support housing',
#  'method performing adaptive voltage scaling av integrated circuit configured perform av',
#  'apparatus method timing recovery wireless transceiver',
#  'apparatus method determine significant bit',
#  'method decoding data',
#  'method fabricating data track use magnetic shift register memory device',
#  'controlling standby power low power device',
#  'sa reference phys virtualization traffic isolation',
#  'apparatus system method differentiating ims connection non-ims connection',
#  'privacy-preserving text language identification using homomorphic encryption',
#  'tear-drop shaped part-span shroud',
#  'process making dihydrocarbyl hydrocarbonphosphonates',
#  'wireless lan dynamic channel access management',
#  'optical microresonator coupling system associated method',
#  'establishing automatic communication delay based prevailing activity factor',
#  'business message tracking system using message queue tracking queue tracking transaction message communicated computer',
#  'multiple sync mark storage system',
#  'apparatus method provisioning endorsement key certificate firmware trusted platform module',
#  'identifying significant grouping customer use customizing digital medium marketing content provided directly customer',
#  'pecvd air gap integration',
#  'spreadsheet programming',
#  'charge pump phase locked loop',
#  'communication channel interposer method program product verifying integrity untrusted subsystem response request',
#  'low-cost strained soi substrate high-performance cmos technology',
#  'polyurethane anticurl backside coating acbc photoconductors',
#  'print head maintenance system ink-jet printer using phase-change ink printing continuous web',
#  'ring transmission network interfacing control function master slave device',
#  'device method utilizing array structure analyte capture',
#  'system assembly pre-heating fuel combined cycle power plant',
#  'method fabricating thermoelectric cooler semiconductor device formed therefrom',
#  'method apparatus system selective duplication subtasks',
#  'method tag plane growth contraction using run length encoded data',
#  'upstream plasma shielded film cooling',
#  'array processor architecture',
#  'method apparatus splitting cache operation multiple phase multiple clock domain',
#  'high selectivity slurry shallow trench isolation processing',
#  'method monitoring function execution',
#  'transaction execution system without transaction support',
#  'spatial security stored data',
#  'apparatus method multi-channel receiver front end',
#  'semiconductor memory component cross-point architecture',
#  'low noise amplifier low noise high isolation bias circuit',
#  'well completion method',
#  'synchronizing data-sets',
#  'high power electrostatic chuck contact',
#  'enabling access aggregated software security information',
#  'method system deploying model-based application application server',
#  'conversion serial bus cycle parallel port command using state machine',
#  'self-contained electronic stowage bin system',
#  'integrated optoelectronic circuit method fabricating',
#  'oblivious transfer hidden access control list',
#  'linearization resistance',
#  'controlling delivery access electronic communication',
#  'dynamic display navigational information',
#  'regulator circuit control method thereof',
#  'generating asserted sensitivity statistical timing',
#  'method system certification path processing',
#  'enhancement positioning pilot channel',
#  'efficient in-band reliability separate cyclic redundancy code frame',
#  'method apparatus true diversity reception single antenna',
#  'pc card wlan system high speed high resolution digital-to analog converter off-line sigma delta conversion storage',
#  'apparatus accumulating transferring lubricant internal combustion engine sump',
#  'cancelling interference determining modulation coding information embedded received spatial stream',
#  'knowledge based access access hierarchy aircraft',
#  'arrestee monitoring variable site boundary',
#  'polling failed device i2c bus',
#  'server amd computer network permit client easily introduced computer network',
#  'spatial transmit/receive isolation method optical communication system',
#  'method apparatus reduction metal artifact ct image',
#  'ultrafiltration system regeneration control',
#  'reel lock coupling engagement mechanism cartridge',
#  'gear lubricant base oil low traction coefficient',
#  'configurable i/os multi-chip module',
#  'interconnect structure method fabrication',
#  'printing process using soft photopolymer plate',
#  'thermoplastic vulcanizate method production',
#  'sensor film system method detection using sensor film',
#  'notification group touch gesture dismissal technique',
#  'recommendation related electronic asset based user search behavior',
#  'method plasma etching tungsten silicide layer gate conductor stack formation',
#  'brush clear occluded stent',
#  'monolithically integrated lateral insulated gate semiconductor device',
#  'apparatus method holding flexible product flat secure position',
#  'contoured stator shroud',
#  'reduced area digital sigma-delta modulator',
#  'porous silicon composite structure large filtration array',
#  'incorporating data cryptographic component ecqv certificate',
#  'donor brush oil barrier layer',
#  'strain tolerant coating environmental protection',
#  'dispensing process fabrication microelectronic package',
#  'system increasing swelling efficiency',
#  'interconnect structure polymer core',
#  'providing access message header',
#  'product recommendation using sentiment semantic analysis',
#  'mapping multiple antenna system using crowdsourcing data',
#  'method apparatus utility-directed prefetching web page local cache using continual computation user model',
#  'apparatus method wide band spectral balance measurement',
#  'wearable transaction device',
#  'inteligent offline caching non-navigated content based usage metric',
#  'determining power supply requirement data processing system',
#  'storage layout data replication',
#  'complex coupled single mode laser dual active region',
#  'system method preventing flashback combustor assembly',
#  'system method detecting vehicle system fault',
#  'universal gate ic transformation netlists implementation',
#  'dynamic learning supplementation intelligent delivery appropriate content',
#  'document image decoding using text line column-based heuristic scoring',
#  'security sandbox',
#  'method hardware apparatus implementing frame alteration command',
#  'column decoder configuration 1t/1c memory',
#  'nonlinear optical surface sensing single thermo-electric detector',
#  'surfacing product listing ad fresh item',
#  'method system using wi-fi display transport mechanism accomplish voice data communication',
#  'buffered crossbar switch method operation',
#  'method apparatus automatic modification semantically significant portion document without document image decoding',
#  'method system using confidence certificate issued certificate authority',
#  'floating command object',
#  'hinged module coupling integrated cable connection',
#  'memory caching scheme distributed-memory network',
#  'multi-touch mouse gaming application',
#  'cross-lingual query suggestion',
#  'bead process control profiler',
#  'on-demand translation application text',
#  'memory refresh rate throttling saving idle power',
#  'method system preventing security breach',
#  'integrated circuit device programmable block analog circuit control',
#  'serial attached small computer system interface sa connection emulation direct attached serial advanced technology attachemnt sata',
#  'tetrahedral interpolation',
#  'system method multi-dimensional average-weighted banding status scoring',
#  'method apparatus dynamically selecting one multiple firmware image booting i/o controller',
#  'creating managing location based meeting',
#  'photoconductors containing filler',
#  'method apparatus ct cardiac diagnostic imaging using motion priori information 3d ultrasound ecg gating',
#  'circuit method reading data transfer sent source synchronous clock signal',
#  'eccentric balanced blisk',
#  'software object security mechanism',
#  'frequency tracking sparse pilot',
#  'reaction vessel',
#  'ceramic monoblock filter metallization pattern providing increased power load handling',
#  'power reset circuit line powered circuit',
#  'avoiding restart error data integration',
#  'multi-stage digital-to-analog conversion circuit method',
#  'self-limiting silicide highly scaled fin technology',
#  'surface modified metal part',
#  'scalable device-to-device interconnection',
#  'programmable controller multiple processor using scanning data acquisition architecture',
#  'method automotive electrical bus management',
#  'method apparatus confirming attribute medium loaded medium tray image production device',
#  'multi-stage filtered optical amplifier',
#  'virtual machine image write leasing',
#  'navigation panel orthogonal slider',
#  'regeneration catalyst hydrogenation sugar',
#  'active noise cancellation featuring secondary path estimation',
#  'mobile device message enabled on-line community bulletin board',
#  'element view toggling',
#  'tubing retrievable injection valve',
#  'method system network service mobile vehicle',
#  'counter-rotating gas turbine engine method assembling',
#  'method system car sharing',
#  'efficient computation variable predictiveness',
#  'transductive feature selection maximum-relevancy minimum-redundancy criterion',
#  'single material optical fiber method',
#  'system method enhanced quality service wireless communication based redundant signal reception two antenna diversity input',
#  'patterned soi formation annihilation buried oxide region processing',
#  'method system performing two-phase commit protocol',
#  'formation evaluation using bit-based active radiation source gamma ray detector',
#  'multiple choke assembly',
#  'method apparatus obtaining variable call parameter suitable use originating sip call via circuit-switched network user equipment device',
#  'facilitating debugging application employing user defined redefined symbol',
#  'method treatment colorectal cancer using 3- 4-amino-1-oxo-1,3-dihydro-isoindol-2-yl -piperidine-2,6-dione',
#  'pwm voltage clamp driver circuit electric fluid dispensing gun method',
#  'method apparatus selectively denying access encoded data',
#  'method apparatus sequence annotation',
#  'neural network-based turbine monitoring system',
#  'demonstration scripting using random-access frame presentation',
#  'system method enhancing spatial effect sound produced sound system',
#  'virtual cultural attache',
#  'custom color printhead module',
#  'generation multi-satellite gps signal software',
#  'system method interactive filter',
#  'method producing advanced rf electronic package',
#  'test executive buffer overwrite detection parameter user-supplied code module',
#  'system method determining use geo-fencing using straight-line distance location',
#  'ofdma control channel interlacing',
#  'electrophotographic imaging member free reflection interference',
#  'management object',
#  'unlatching mechanism optical transceiver',
#  'multiple nfc card application multiple execution environment',
#  'mounting shock absorber assembly borehole telemetry apparatus',
#  'half pixel motion estimation motion video signal encoding',
#  'enhancement carrier concentration as-containing contact layer',
#  'system method uplink timing synchronization conjunction discontinous reception',
#  'remote control medium content delivery digital medium recorder',
#  'method avoiding multiple color moire color halftoning',
#  'system recovery',
#  'combination field radio modem amplifier',
#  'method system efficiently storing semantic web statement relational database',
#  'mechanism unequivocally referencing content web 2.0 application',
#  'plasma processing method apparatus control plasma excitation power',
#  'client category configuration',
#  'disambiguating residential listing search result',
#  'method apparatus handling image data unsuccessful transfer remotely located device',
#  'integrated circuit isolation process',
#  'method resizing hole',
#  'temporal-based professional similarity',
#  'memory coherence protocol enhancement using cache line access frequency',
#  'actuation mechanism use keyboard mobile computing device',
#  'strained channel region transistor employing source drain stressor system including',
#  'real-time mapping navigation multiple medium type metadata-based infrastructure',
#  'full width array scanning spectrophotometer',
#  'system method selectively scrambling multidimensional digital frame structure communication',
#  'early preamble transmission',
#  'binding digital license portable device like digital right management drm system checking checking digital license portable device like',
#  'seat belt buckle assembly',
#  'system high power chip low power chip low interconnect parasitics',
#  'system method associate broadcast radio content transaction via internet server',
#  'method high density data storage read-back',
#  'substituted triazolo 1,5-a pyridine triazolo 1,5-a pyrazines lsd1 inhibitor',
#  'nonpolar solid phase change ink composition comprising quinacridone nanoscale pigment particle',
#  'process preparing hydroxylated aromatics hydrogen oxygen',
#  'antibiotic unphenelfamycin phenelfamcyins a-f',
#  'software visualization using code coverage information',
#  'method oxidizing carbonaceous material diesel particulate filter exhaust gas system',
#  'method structure forming self-aligned borderless contact strain engineered logic device',
#  'deployable reflector antenna tensegrity support architecture associated method',
#  'reactor pressure vessel vented head',
#  'semiconductor structure containing low-resistance source drain contact',
#  'document dispenser operator security override',
#  'method circuit preventing forward bias parasitic diode integrated circuit',
#  'method providing polysilicon spacer implantation',
#  'slurry monitoring system',
#  'washing machine spraying ring',
#  'method system close proximity wireless communication',
#  'leakage-aware voltage regulation circuit method',
#  'multimedia control system method controlling multimedia program presentation',
#  'temperature and/or process independent current generation circuit',
#  'digital watermarking television service',
#  'method system accessing saved patient context clinical information system',
#  'method system computer program product spoken language grammar evaluation',
#  'system method data communication using trellis coded modulation turbo trellis coded modulation combination constellation shaping without precoding using concatenated coding scheme working non-error free operation point',
#  'on-demand code version switching',
#  'self test core unpredictable latency',
#  'interleaved immersion-cooling apparatus method cooling electronic subsystem',
#  'apparatus associated method configuring page message used page access terminal radio communication system extra partial identity bit extracted page message',
#  'polyurethane derived novel polyester polycarbonates',
#  'predictive popular content replication',
#  'method system determining multiple unused register processor',
#  'forwarding message communication network',
#  'method constructing approximated dynamic huffman table use data compression',
#  'remote operated circuit breaker panel',
#  'geospatial modeling system related method using multiple source geographic information',
#  'reducing power/area requirement support sleep mode operation regulator turned',
#  'load balancing distribution power supply system',
#  'method re-executing process computer system fault correction',
#  'store peripheral component interconnect pci function control instruction',
#  'fast approach finding minimum maximum value large data set using simd instruction set architecture',
#  'semiconductor etch speed modification',
#  'register liveness analysis simd architecture',
#  'non-volatile memory crosspoint repair',
#  'framer method architecture circuit programmable symbol selection',
#  'single piece slotted ferromagnetic sputtering target sputtering apparatus',
#  'adaptive interpolation artifact reduction image',
#  'multi-zone passageway monitoring system method',
#  'method system centralized network usage tracking',
#  'graphic flow unlimited number connection shape',
#  'voltage regulator staggered pole-zero compensation network',
#  'software-controlled cache set management',
#  'method system inventory control secure stock feeder finisher',
#  'system method generating refinement category set search result',
#  'using high priority thread boost cpu clock rate',
#  'method controlling interference femto cell deployment',
#  'energy efficient capacity control air conditioning system',
#  'method fabricating carbon nanotube transistor silicon soi substrate',
#  'convertible fan engine',
#  'displaying interacting touch contextual user interface',
#  'alternative profiling methodology tool analysing competitive benchmark',
#  'system method optimizing read-modify-write operation raid 6 volume',
#  'converter topology control',
#  'geotiles finding relevant result geographically distributed set',
#  'system method reducing combustion dynamic turbomachine',
#  'flexible peripheral device positioner',
#  'transitioning port communication system active state standby state',
#  'establishing controlling audio voice back channel wi-fi display connection',
#  'system cleaning cart drive component three-dimensional object printing system',
#  'detecting trend electronic communication steganography analysis',
#  'interconnect system method ethernet network',
#  'microemulsion coformulation graminicide water-soluble herbicide',
#  'parallel plane memory processor coupling 3-d micro-architectural system',
#  'dual-property alpha-beta titanium alloy forging',
#  'sealing tube material high pressure short-arc discharge lamp',
#  'electromagnetic interference reduction',
#  'surface-mount pointing device',
#  'making electrical connection circuit board integrated circuit',
#  'security enabled network access control',
#  'bimodal intrusion detection optical fiber communication system using graded index fiber',
#  'running plurality instance application',
#  'system heating fuel',
#  'system method device energy power metering',
#  'method apparatus independently controlling electric parameter impedance matching network',
#  'categorizing image software failure',
#  'mapping shared address bit accessing data memory pagemode cache status memory word mode',
#  'fluid probe fiber bragg grating sensor',
#  'quick attachment carrier assembly',
#  'method system fast volume cropping three-dimensional image data',
#  'energy absorbing vehicle fender',
#  'pitch-based subresolution assist feature design',
#  'viral application distribution',
#  'method apparatus enhancing access point database',
#  'method structure enabling controlled spacer rie',
#  'thermal control semiconductor wafer reactive ion etching',
#  'peak average power ratio reduction ofdm signal',
#  'system method interactive beef cattle marketplace',
#  'process applying coating system',
#  'range microwave safety door',
#  'video block transform',
#  'inter-shader attribute buffer optimization',
#  'high voltage electric submersible pump cable',
#  'automatic generation question-answer pair conversational text',
#  'stacked metal silicide gate structure barrier',
#  'automatic fault current protection locomotive propulsion system',
#  'tape head facing beam head chip positioned recess thereof',
#  'optimization-based process scheduling method system',
#  'dynamic infrastructure monitoring service level agreement',
#  'packet multiplexing multi-channel audio',
#  'thermally expanded multiple core fiber',
#  'structure method reduce shorting stt-mram device',
#  'management computer security event across distributed system',
#  'system high-speed data transfer using sequence overlapped global pointfer signal generating corresponding sequence non-overlapped local pointer signal',
#  'power supply obliquely impinging airflow',
#  'nano-filter method forming method filtration',
#  'social dilemma software evaluating online interactive society',
#  'method system providing notification user becomes available communicating',
#  'single pas color printer facet matching',
#  'lubricating micro-machined device using fluorosurfactants',
#  'complex anionic dye polyquaternary amine',
#  'multi-carrier operation wireless system',
#  'seamless computer system remote control',
#  'method material depositing film semiconductor substrate',
#  'epoxy coating using acrylate ester polyetherpolyamines piperazine',
#  'method system monitoring security container',
#  'user interface framework technique',
#  'uplink resource allocation transport block size determination unlicensed spectrum',
#  'method unit deskewing signal',
#  'non-intrusive background synchronization authentication required',
#  'elastomer composition method',
#  'agricultural implement marker foldable compound angle',
#  'process controlling exposure dose focus parameter',
#  'method preventing temperature condition gas turbine engine',
#  'system method noise control medical imaging system',
#  'fuser fixing member self-healing fuser fixing member',
#  'automated service blocking malware host',
#  'scan verification scan-chain device test',
#  'sram layout double patterning',
#  'synthesis process',
#  'system method determining return-on-investment semiconductor data storage fabrication facility',
#  'multi-response vibration damper assembly',
#  'touch-panel display device portable equipment',
#  'water purification apparatus',
#  'baud rate timing recovery nyquist pattern communication system',
#  'system method enabling channel access enhancement existing communication network',
#  'silicon/silcion germaninum/silicon body device embedded carbon dopant',
#  'cerium oxide containing ceramic component coating semiconductor processing equipment method manufacture thereof',
#  'rule adjustment visualization physical location data',
#  'non-integer pixel sharing video encoding',
#  'system method reducing seek time read operation mirrored dasd file',
#  'method creating non-patterned security element',
#  'low power operation networked device',
#  'clothes fabric type blend detection method apparatus',
#  'backlighting device',
#  'method apparatus thinning printed image',
#  'composition method enhancing delivery nucleic acid cell modifying expression target gene cell',
#  'transition connection device radio frequency point sale transaction system',
#  'client side reconciliation typographical error message input-limited device',
#  'method creating application-consistent remote copy data using remote mirroring',
#  'integration energy storage device onto substrate microelectronics mobile device',
#  'synthetic resin composition',
#  'system method deblurring image',
#  'clock multiplier structure fixed speed testing integrated circuit',
#  'high resolution interferometric optical frequency domain reflectometry ofdr beyond laser coherence length',
#  'transformation asynchronous transactional messaging language web service compatible language',
#  'stiched ic layout method system program product',
#  'method system dynamic service flow using available battery power',
#  'method apparatus corrosion sensing',
#  'detection unknown scenario',
#  'transparent polymeric composition comprising polysiloxane-polycarbonate copolymer article made therefrom method making',
#  'uplink coordinated multi-point',
#  'self-repair integrated circuit repair method',
#  'dynamic determination number served medium content',
#  'early fouling detection',
#  'integrated circuit package improved power signal connection',
#  'drug metabolizing enzyme',
#  'analog front-end coherent in-phase demodulation data acquisition system resistivity image tool',
#  'network controller sideband interface port controller',
#  'organizing resource collection facilitate efficient reliable resource access',
#  'electroactive layer coupled flexible display',
#  'nonlinear polymer composite method making',
#  'navigation using dynamic speed limit',
#  'method aligning device layer semiconductor device',
#  'apparatus method configuring data plane behavior network forwarding element',
#  'polymer comprising superacidic group us thereof',
#  'circuit controlling frequency phase voltage controlled oscillator data smoother streaming cartridge tape drive',
#  'high density high q capacitor top protective layer',
#  'energy relief control mechanical ventilator',
#  'concurrent read write operation serial flash device',
#  'system level testing multi-threading functionality',
#  'formation germanium-containing channel region thermal condensation utilizing oxygen permeable material',
#  'notification breakthrough status profile',
#  'hand-held target locator',
#  'aerial refueling boom boom pivot',
#  'burst access memory system',
#  'transistor comprising doped region-gap-doped region structure method fabrication',
#  'polymer mixture composed aromatic polycarbonate optionally polyalkyleneterephthalate graft copolymer',
#  'current multiplexing circuit optical power monitoring',
#  'process-mode independent driver model',
#  'dry agricultural material management',
#  'method composition polishing silicon-containing substrate',
#  'hierarchical memory magnetoresistive random-access memory mram architecture',
#  'apparatus program product method utilizing intelligent contact management',
#  'illumination source millimeter wave imaging',
#  'switching connection protocol',
#  'visibly transparent dye through-transmission laser welding',
#  'magnetic tape medium servo pattern',
#  'direct detection optical psk signal',
#  'solar cell metallizations containing metal additive',
#  'content adaptive noise reduction filtering image signal',
#  'no-sulfur fuel lubricity additive',
#  'automatic synchronization receiver navigational system',
#  'access truck sleeper trim operation',
#  'residential electricity meter',
#  'method system gesture classification',
#  'radome detuned element continuous wire',
#  'method anchoring seal ring substrate using vias assembly including anchored seal ring',
#  'visual preview search result',
#  'compression connector',
#  'method determining vertical horizontal resistivity relative dip anisotropic earth formation arbitrary electro-magnetic antenna combination orientation additional rotation positon measurement',
#  'system method initializing dynamic model state using kalman filter',
#  'isoindolinone kinase inhibitor',
#  'polymer solution sizing paper',
#  'modifying fusion offset data sequential stereoscopic image frame',
#  'packet filter based access control',
#  'implementing wireless power transfer 60 ghz mmwave communication',
#  'shared memory controller',
#  'apparatus method enabling database batch update without modifying generated code',
#  'marine vessel apparatus mounting marine drive marine vessel',
#  'thermoelectrics composition comprising nanoscale inclusion chalcogenide matrix',
#  'method apparatus handling policy charging control rule quality service rule modification failure',
#  'apparatus method cooling semiconductor device',
#  'method apparatus generating condensed version video sequence including desired affordances',
#  'main memory system checkpointing protocol fault-tolerant computer system using exclusive-or memory',
#  'sleep protection',
#  'solvent-assisted continuous emulsification process producing polyester latex',
#  'filtering event log entry',
#  'generating molecular encoding information data storage',
#  'receiver alias rejection improvement adding offset',
#  'wireless system performance modeling',
#  'closure bucket turbo-machine',
#  'cloud-connectable middleware appliance',
#  'parallel high-speed communication link redundant channel architecture',
#  'device reducing impact distortion microscope',
#  'firmware architecture supporting safe update multiple processor type',
#  'drive nut assembly door operator',
#  'translation address cache microprocessor',
#  'structural epoxy resin adhesive containing chain-extended elastomeric tougheners capped phenol polyphenol aminophenol compound',
#  'carrier tape manufacturing method said carrier tape',
#  'minimizing interference non-associated user',
#  ...]

# %%
cvectorizer = CountVectorizer(min_df=4, max_features=2000, ngram_range=(2,3))
cvz = cvectorizer.fit_transform(sample['title_lemma'])

n_topics = 10
n_iter = 1000
lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_model.fit_transform(cvz)
# Out:
# WARNING:lda:all zero row in document-term matrix found

# %%
n_top_words = 8
topic_summaries = []

topic_word = lda_model.topic_word_  # get the topic words
vocab = cvectorizer.get_feature_names()

for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    topic_summaries.append(', '.join(topic_words))

# %%
# topic_word

# %%
tsne_model = TSNE(n_components=2, random_state=0, learning_rate=30, n_iter=300, angle=0.7, init='pca')
tsne_lda = tsne_model.fit_transform(X_topics)

# %%
doc_topic = lda_model.doc_topic_
lda_keys = []
for i, tweet in enumerate(sample['title']):
    lda_keys += [doc_topic[i].argmax()]

# %%
plot_lda = bp.figure(plot_width=700, plot_height=600, title="LDA topic visualization",
    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
    x_axis_type=None, y_axis_type=None, min_border=1)

# %%
lda_df = pd.DataFrame(tsne_lda, columns=['x','y'])
lda_df['title'] = sample['title_lemma'].tolist()
lda_df['sector'] = sample['sector'].tolist()
lda_df['ticker'] = sample['ticker'].tolist()
lda_df.head()
# Out:
#           x         y                                              title  \
# 0  0.590467  1.369476  signaling parameterized quality service qos su...
# 1  0.590467  1.369476  optimization polycarbonate preparation transes...
# 2 -5.596375 -1.139622  operation control system ensuring availability...
# 3 -4.307505  5.045486                        real-time typing assistance
# 4  0.590467  1.369476                                    local collector
#
#                    sector ticker
# 0  Information Technology    TXN
# 1             Industrials     GE
# 2  Information Technology    IBM
# 3  Information Technology   MSFT
# 4              Financials    BAC

# %%
# Counter(sample['sector'])

# %%
lda_df['topic'] = lda_keys
lda_df['topic'] = lda_df['topic'].map(int)

# %%
colormap = np.array(["#6d8dca", "#69de53", "#723bca", "#c3e14c", "#c84dc9", "#68af4e", "#6e6cd5",
"#e3be38", "#4e2d7c", "#5fdfa8", "#d34690", "#3f6d31", "#d44427", "#7fcdd8", "#cb4053", "#5e9981",
"#803a62", "#9b9e39", "#c88cca", "#e1c37b", "#34223b", "#bdd8a3", "#6e3326", "#cfbdce", "#d07d3c",
"#52697d", "#7d6d33", "#d27c88", "#36422b", "#b68f79"])

# %%
# plot_lda.scatter(source=lda_df, x='x', y='y', color=colormap[lda_keys])

# hover = plot_lda.select(dict(type=HoverTool))
# hover.tooltips={"title":"@title", "topic":"@topic", "sector":"@sector", "ticker":"@ticker"}
# show(plot_lda)

# %% [markdown]
# # visualization of topics using pyLDAvis

# %%
lda_df['len_docs'] = lda_df['title'].apply(lambda x: len(x.split(' ')))

# %%
def prepareLDAData():
    data = {
        'vocab': vocab,
        'doc_topic_dists': lda_model.doc_topic_,
        'doc_lengths': list(lda_df['len_docs']),
        'term_frequency':cvectorizer.vocabulary_,
        'topic_term_dists': lda_model.components_
    } 
    return data

# %%
ldadata = prepareLDAData()

# %%
import pyLDAvis
pyLDAvis.enable_notebook()

# %%
prepared_data = pyLDAvis.prepare(**ldadata)
# Out:
# /Users/annzhong/anaconda/lib/python3.6/site-packages/pyLDAvis/_prepare.py:387: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   topic_term_dists = topic_term_dists.ix[topic_order]

# %%
pyLDAvis.save_html(prepared_data,'./pyldadavis.html')

# %%
test = lda_df[lda_df['topic'] == 0]
test
# Out:
#              x         y                                              title  \
# 0     0.590467  1.369476  signaling parameterized quality service qos su...
# 1     0.590467  1.369476  optimization polycarbonate preparation transes...
# 4     0.590467  1.369476                                    local collector
# 7     0.590467  1.369476                    pseudo wire mobility management
# 8     0.192266 -3.692449  technique introduce advanced functional behavi...
# 9     0.590467  1.369476                    microdisplay eye gaze detection
# 10    0.590467  1.369476  multi-space distribution pattern recognition b...
# 13   -4.480450  6.587622  method apparatus binding subscriber authentica...
# 14    0.590467  1.369476  intelligent migration device different hardwar...
# 18    0.590467  1.369476  inkjet ink comprising modified pigment attache...
# 19    0.590467  1.369476  desktop environment color alert system printin...
# 21    0.590467  1.369476     gate-induced strain mo performance improvement
# 22   -5.305892  1.159195  securely publishing user profile information a...
# 23    0.590467  1.369476                       radio frequency heating fork
# 24    0.590467  1.369476       methylated methylolated melamine composition
# 25    0.590467  1.369476        optimizing latest user defined class loader
# 26    0.590467  1.369476  automatic identification modifier term title s...
# 28    0.192266 -3.692449  hierarchical feedback channel state informatio...
# 29    0.590467  1.369476  isolator depending component electrostatic fie...
# 32    0.192266 -3.692449  method facilitating user input handheld electr...
# 34    0.590467  1.369476  cache management asynchronous memory move oper...
# 36    0.392980  1.204232  technique performing arbitrary width integer a...
# 37    0.393171  1.203849  method modifying copy protected video signal n...
# 38    0.590467  1.369476           showing correcting irregularity schedule
# 39    0.590467  1.369476  liquid-cooled grounded heatsink diode rectifie...
# 40    0.590467  1.369476       automatic reuse user-specified content query
# 42   -5.305892  1.159195       photovoltaic device electroplated metal grid
# 46    0.590467  1.369476  link chain verification validation methodology...
# 52    0.590467  1.369476           light emitting diode improved efficiency
# 53    0.590467  1.369476                  power electronic module packaging
# ...        ...       ...                                                ...
# 2953  0.590467  1.369476    compensating power spectral density power level
# 2954  0.590467  1.369476                  testing configuration environment
# 2955  0.590467  1.369476                            epoxy resin formulation
# 2957  0.192266 -3.692449  optimization database network traffic based up...
# 2959  0.590467  1.369476  service identification legacy source code usin...
# 2963  0.590467  1.369476         address translation logic use gps receiver
# 2965  0.590467  1.369476  coordination clear channel assessment across c...
# 2966  0.590467  1.369476          storage stamp information error diffusion
# 2967  0.590467  1.369476  receiving data interleaved multiple concurrent...
# 2968  0.590467  1.369476                    feedback receive path rf filter
# 2969  0.590467  1.369476  eliminating coalescing bypassing port memory a...
# 2971  0.590467  1.369476  message integration framework multi-applicatio...
# 2974  0.590467  1.369476  system editing query condition calculation for...
# 2975  0.590467  1.369476  mobile node ad hoc network routing controlling...
# 2978  0.590467  1.369476                     antenna tuning control circuit
# 2979  0.590467  1.369476  loading identifying digital right management o...
# 2981  0.590467  1.369476  hardware firmware encryption mechanism using u...
# 2982  0.590467  1.369476       erasable nonvolatile memory sidewall storage
# 2983  0.590467  1.369476             microwave polarization control network
# 2984  0.590467  1.369476                         electrical charging system
# 2985  0.590467  1.369476  method shortening enumeration tightly coupled ...
# 2986  0.590467  1.369476          ecc mechanism set associative cache array
# 2988  0.590467  1.369476            flexible head probe sort interface unit
# 2989  0.590467  1.369476                      generating document structure
# 2990  0.590467  1.369476  call center system dynamic determination appro...
# 2991  0.590467  1.369476  autonomic definition management distributed ap...
# 2992  0.590467  1.369476        method surface enhancement fluid jet impact
# 2995  0.590467  1.369476        hole-filling three-prong temporary fastener
# 2996  0.590467  1.369476            self-planarized gold interconnect layer
# 2997  0.393174  1.203835  resilient interworking shortest path bridging ...
#
#                             sector ticker  topic  len_docs
# 0           Information Technology    TXN      0         6
# 1                      Industrials     GE      0         4
# 4                       Financials    BAC      0         2
# 7                 Telecom Services   QCOM      0         4
# 8           Information Technology    IBM      0        13
# 9           Information Technology   INTC      0         4
# 10          Information Technology   MSFT      0         9
# 13                Telecom Services   QCOM      0         9
# 14                Telecom Services   QCOM      0         7
# 18    Raw & Intermediate Materials    CBT      0         8
# 19          Information Technology    XRX      0         7
# 21          Information Technology   INTC      0         5
# 22          Information Technology   MSFT      0         9
# 23          Information Technology    HRS      0         4
# 24                Consumer Staples    MON      0         4
# 25          Information Technology    IBM      0         6
# 26          Information Technology   LNKD      0         6
# 28                Telecom Services   QCOM      0         7
# 29                     Industrials   AGCO      0         7
# 32          Information Technology   BBRY      0        11
# 34          Information Technology    IBM      0         6
# 36          Information Technology   NVDA      0        11
# 37              Consumer Cyclicals   ROVI      0         9
# 38          Information Technology   MSFT      0         4
# 39                     Industrials     GE      0         9
# 40          Information Technology   BBRY      0         5
# 42                       Utilities   SCTY      0         5
# 46          Information Technology    TXN      0         7
# 52          Information Technology   INTC      0         5
# 53                     Industrials     GE      0         4
# ...                            ...    ...    ...       ...
# 2953              Telecom Services   QCOM      0         6
# 2954        Information Technology    IBM      0         3
# 2955  Raw & Intermediate Materials    DOW      0         3
# 2957        Information Technology    IBM      0         8
# 2959        Information Technology    IBM      0         9
# 2963              Telecom Services   QCOM      0         6
# 2965              Telecom Services   QCOM      0        10
# 2966        Information Technology    XRX      0         5
# 2967        Information Technology    ELX      0        11
# 2968              Telecom Services   QCOM      0         5
# 2969        Information Technology    IBM      0         7
# 2971            Consumer Cyclicals   FICO      0         5
# 2974        Information Technology   ORCL      0         7
# 2975        Information Technology   GOOG      0        12
# 2978            Consumer Cyclicals   VOXX      0         4
# 2979        Information Technology   MSFT      0         7
# 2981        Information Technology    TXN      0         9
# 2982        Information Technology    IBM      0         5
# 2983                   Industrials    ITT      0         4
# 2984            Consumer Cyclicals     VC      0         3
# 2985              Telecom Services   QCOM      0         7
# 2986        Information Technology    IBM      0         6
# 2988        Information Technology   INTC      0         6
# 2989        Information Technology    IBM      0         3
# 2990                    Financials    BAC      0         7
# 2991        Information Technology    IBM      0         6
# 2992                   Industrials     GE      0         6
# 2995                   Industrials     BA      0         4
# 2996        Information Technology   ISIL      0         4
# 2997        Information Technology   CIEN      0         9
#
# [1833 rows x 7 columns]

# %%
Counter(test['sector'])
# Out:
# Counter({'Consumer Cyclicals': 61,
#          'Consumer Staples': 25,
#          'Energy': 56,
#          'Financials': 100,
#          'Healthcare': 97,
#          'Industrials': 446,
#          'Information Technology': 1846,
#          'Raw & Intermediate Materials': 52,
#          'Telecom Services': 132,
#          'Utilities': 2})

# %%
test.shape
# Out:
# (81, 7)
