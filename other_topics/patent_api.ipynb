# %%
import pandas as pd
import numpy as np
import requests

# available choices of search key words can be found from this link:
# http://www.patentsview.org/api/patent.html

# %%
# api_url = 'http://www.patentsview.org/api/patents/query?\
# q={"_and":[\
# {"_gte":{"patent_date":"2000-01-01"}}, \
# {"_text_all":{"patent_abstract":"P38-kinase"}}]}&\
# f=["patent_number","patent_date","assignee_organization","patent_title",\
# "patent_abstract","patent_num_combined_citations","inventor_first_name",\
# "inventor_last_name","app_type"]&\
# o={"page":1, "per_page":5000}'

# %%
api_url = 'http://www.patentsview.org/api/patents/query?\
q={"_and":[\
{"_gte":{"patent_date":"2000-01-01"}}, \
{"_contains":{"assignee_organization":"International Business Machine"}}]}&\
f=["patent_number","patent_date","assignee_organization","patent_title",\
"patent_abstract","patent_num_combined_citations","inventor_first_name",\
"inventor_last_name","cpc_category"]&\
o={"page":1, "per_page":1000}'

session = requests.Session()
session.mount('http://', requests.adapters.HTTPAdapter(max_retries=3))
raw_data = session.get(api_url)
txt = raw_data.json()

# %%
len(txt)
# Out:
# 3

# %%
categories = []
for i in range(len(txt)):    
    categories.append(txt['patents'][i]['cpcs'])

# %%
categories
# Out:
# [[{'cpc_category': 'inventional'}, {'cpc_category': 'additional'}],
#  [{'cpc_category': 'inventional'}, {'cpc_category': 'additional'}],
#  [{'cpc_category': 'inventional'}]]

# %%
patent_numbers = []
assignees = []
inventors = []
patent_type = []
for patent in txt['patents']:
    patent_numbers.append(patent['patent_number'])
    assignees.append(list(patent['assignees'][0].values())[0])
    patent_type.append(patent['patent_type'])
    names = []
    for i in range(len(patent['inventors'])):
        inventor_name = ' '.join(list(patent['inventors'][i].values()))
        names.append(inventor_name)
    inventors.append(', '.join(names))

# %%
patent_urls = []
for patent_number in patent_numbers:
    patent_url = "http://patft.uspto.gov/netacgi/nph-Parser?Sect2=PTO1&\
Sect2=HITOFF&p=1&u=/netahtml/PTO/search-bool.html&r=1&f=G&l=50&d=PALL&\
RefSrch=yes&Query=PN/{}".format(patent_number)
    patent_urls.append(patent_url)

# %%
result = txt['patents']
result_df = pd.DataFrame(result)

# %%
# result_df['url'] = patent_urls
result_df['assignees'] = assignees
result_df['inventors'] = inventors
result_df['patent_type'] = patent_type

# %%
result_df = result_df.rename(columns={'patent_num_combined_citations':'citations'})

# %%
result_df.to_pickle('microsoft2000.pkd')

# %% [markdown]
# # 作死开始

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import nltk
from nltk.corpus import stopwords

# %%
abstract = list(result_df['patent_abstract'])

# %%
vectorizer = TfidfVectorizer(ngram_range=(3,3), stop_words=stopwords.words())

# %%
tfidf = vectorizer.fit_transform(abstract)

# %%
# from sklearn.cluster import AffinityPropagation

model = AffinityPropagation(preference=-5)
model.fit(tfidf)
cluster_centers_indices = model.cluster_centers_indices_
n_clusters = len(cluster_centers_indices)

# %%
# -5: 15
n_clusters
# Out:
# 15

# %%
k = 15
km_model = KMeans(n_clusters=k, init='k-means++', max_iter=50, n_init=2)
km_model.fit(tfidf)

order_centroids = km_model.cluster_centers_.argsort()[:, ::-1]

# %%
names = vectorizer.get_feature_names()

# %%
cluster = dict()
for i in range(k):
    cluster[i] = []
    for ind in order_centroids[i, :15]:
        cluster[i].append(names[ind])

# %%
text = [s for l in list(cluster.values()) for s in l]
text = ' '.join(text)

from wordcloud import WordCloud, STOPWORDS
from os import path
from scipy.misc import imread
import matplotlib.pyplot as plt
import random
from wordcloud import WordCloud, STOPWORDS

# %%
#text = 'all your base are belong to us all of your base base base'
wordcloud = WordCloud(font_path='/Library/Fonts/Verdana.ttf',
                      background_color='white',
                      relative_scaling = 1.0,
                      width=800, height=600,
                      stopwords = STOPWORDS,
                  ).generate(text)

# %%
plt.figure(figsize=(12,9))
plt.imshow(wordcloud, aspect='auto',)
plt.axis("off")
plt.show()

# %%
cols = []
for i in range(k):
    cols.append('cluster'+str(i))

# %%
cluster_df = pd.DataFrame(cluster)
cluster_df.columns = cols

# %%
cluster_df.T
# Out:
#                                       0                             1   \
# cluster0   apparatus article manufacture      method apparatus article
# cluster1          multisystem log stream         log stream compressed
# cluster2      present invention provides     invention provides method
# cluster3         internal area enclosure          insulator vent tubes
# cluster4    distributed system structure        switch multiple memory
# cluster5       present invention relates   invention relates generally
# cluster6           printed circuit board             spin valve sensor
# cluster7           silicon insulator soi              trench side wall
# cluster8        method present invention         one particles surface
# cluster9          liquid crystal display        crystal display device
# cluster10         data processing system        client computer system
# cluster11        integrated circuit chip      present invention allows
# cluster12      chemical reaction product    surface metallic structure
# cluster13     present invention directed            different level l3
# cluster14    according present invention  embodiment present invention
#
#                                      2                                   3   \
# cluster0         method comprises steps                 data storage device
# cluster1             adjusted real time      system multisystem environment
# cluster2         provides method system           provides method apparatus
# cluster3      conductors insulator vent           atmosphere prevent access
# cluster4      supported node controller            node controller receives
# cluster5          relates generally new  particularly invention encompasses
# cluster6       computer program product            graphical user interface
# cluster7        field effect transistor            field effect transistors
# cluster8       subset component vectors           groups descriptor vectors
# cluster9       object present invention                  color filter layer
# cluster10    processing system includes              server computer system
# cluster11            current source fet               circuit chip assembly
# cluster12          top surface metallic                   metal oxide layer
# cluster13     invention directed method                  first object first
# cluster14  preferred embodiment present          physical health indicators
#
#                                          4                               5   \
# cluster0                stored data storage            database stored data
# cluster1    systems multisystem environment        stream compressed system
# cluster2              printed circuit board    accordance present invention
# cluster3   electrical conductors surrounded         prevent access internal
# cluster4         subsystems multiple master         address switch multiple
# cluster5           invention relates method  thereof particularly invention
# cluster6       accordance present invention         field effect transistor
# cluster7                  gate body contact          faceted crystal region
# cluster8          transfer error occurrence           error occurrence rate
# cluster9                crystal display lcd                  side lcd panel
# cluster10            within data processing        processing system method
# cluster11             circuit chip includes    substrate integrated circuit
# cluster12           ammonia polishing wafer       example ammonia polishing
# cluster13                object first class             dual gate structure
# cluster14    according preferred embodiment     present invention apparatus
#
#                                       6                               7   \
# cluster0        storage device connected    article manufacture computer
# cluster1   compressed system ascertained    environment frequency system
# cluster2                layers least one             back channel region
# cluster3           vent tubes positioned    positioned adjacent parallel
# cluster4    controller receives commands      structure contains address
# cluster5    process thereof particularly  particularly present invention
# cluster6              includes least one             data storage system
# cluster7          body contact structure               trench side walls
# cluster8       nitrogen containing layer     target addresses sequential
# cluster9    dynamically extendible table         first second substrates
# cluster10          method apparatus data       apparatus data processing
# cluster11      heat generating component      surface integrated circuit
# cluster12     detection endpoint removal   process selectively generates
# cluster13           logical device state        device state information
# cluster14           wire pair connectors               twisted wire pair
#
#                                          8                              9   \
# cluster0   manufacture computer implemented      device connected computer
# cluster1                log stream adjusted  frequency systems multisystem
# cluster2          invention provides system               cross bar switch
# cluster3             allow airflow internal      tubes positioned adjacent
# cluster4               nodes supported node     memory subsystems multiple
# cluster5              onto module component          preform thermal paste
# cluster6      chemical mechanical polishing     present invention includes
# cluster7            effect transistors fets     intermediate silicon layer
# cluster8       addresses sequential address            data transfer error
# cluster9             first conductive layer         first second container
# cluster10       processing system disclosed              field text string
# cluster11         planar interconnect layer              hard mask pattern
# cluster12           product example ammonia        overlying stopping film
# cluster13          associated function area           closed cage molecule
# cluster14                   soi mos devices     invention apparatus method
#
#                                              10  \
# cluster0             disclosed method comprises
# cluster1         compressed systems multisystem
# cluster2           embodiment present invention
# cluster3           adjacent parallel conductors
# cluster4             multiple memory subsystems
# cluster5             invention relates improved
# cluster6                  method system include
# cluster7                     silicon base layer
# cluster8   information corresponding confidence
# cluster9              second container portions
# cluster10                      second data item
# cluster11       integrated circuit interconnect
# cluster12              film process selectively
# cluster13                  mobile agent message
# cluster14               selected memory address
#
#                                               11  \
# cluster0                          least one user
# cluster1           compressed system multisystem
# cluster2            preferred embodiment present
# cluster3           parallel conductors insulator
# cluster4                  commands master device
# cluster5                  high density pluggable
# cluster6                 low dielectric constant
# cluster7                       type silicon base
# cluster8   categorized information corresponding
# cluster9                    crystal display cell
# cluster10                 client data processing
# cluster11          encapsulated prior mechanical
# cluster12                     wafer nitride film
# cluster13                   refers second object
# cluster14             present invention includes
#
#                                         12                              13  \
# cluster0      accordance present invention    manufacture memory structure
# cluster1               time thus frequency   system compresses multisystem
# cluster2    selectively removable material          anti reflection layers
# cluster3                  vent tubes allow   enclosure external atmosphere
# cluster4         system structure contains         multiple master devices
# cluster5       density pluggable connector     laminate magnet significant
# cluster6                   read write head             air bearing surface
# cluster7            bulk silicon substrate    bulk semiconductor substrate
# cluster8   corresponding confidence levels        maximum command response
# cluster9               type liquid crystal  received intensity information
# cluster10                  first data item          cache memory hierarchy
# cluster11     mechanical bonding packaging        prior mechanical bonding
# cluster12            target film overlying        reaction product example
# cluster13             dual blocked polymer          temporary storage area
# cluster14             magnetic pole region       present invention provide
#
#                                        14
# cluster0       article manufacture memory
# cluster1              log stream relative
# cluster2           energy active material
# cluster3   includes electrical conductors
# cluster4              set nodes supported
# cluster5           holes integrated metal
# cluster6             random access memory
# cluster7                 soi field effect
# cluster8            command response time
# cluster9               dark mesh material
# cluster10      determination made whether
# cluster11       wherein chip encapsulated
# cluster12         polishing wafer nitride
# cluster13             relaxed sige buffer
# cluster14            time key certificate
