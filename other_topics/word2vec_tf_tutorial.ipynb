# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# %%
def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
count = [['UNK', -1]]
count
# Out:
# [['UNK', -1]]

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    
    return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# >>> collections.deque(['anarchism', 'originated', 'as','a','term', 'of', 'abuse', 'first', 'used', 'against'], maxlen=5)
# out[]: deque(['of', 'abuse', 'first', 'used', 'against'])
# this return the last 'maxlen' words in a list

# %%
# Step 3: Function to generate a training batch for the skip-gram model.

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
            
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# %%
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 2 of -> 195 term
# 2 of -> 3134 abuse
# 3134 abuse -> 2 of
# 3134 abuse -> 46 first
# 46 first -> 3134 abuse
# 46 first -> 59 used
# 59 used -> 156 against
# 59 used -> 46 first

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.

valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

    # Add variable initializer.
    init = tf.global_variables_initializer()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  263.246856689
# Nearest to the: accelerating, tecnol, frazier, diverging, gallurese, regains, convalescence, xiaoping,
# Nearest to more: demokratische, declining, surveillance, readiness, shambhala, bouncing, trim, major,
# Nearest to they: automobiles, cad, cain, bottleneck, peress, pickled, extinguisher, nomad,
# Nearest to world: remedy, harcourt, vaux, glidrose, lector, vegetarianism, haphazard, roddenberry,
# Nearest to during: eddy, fable, ced, weiser, every, separatist, aquaria, excommunicate,
# Nearest to who: mamma, sda, tampa, extract, became, images, tasso, combustion,
# Nearest to of: fujimori, gila, coins, bettors, brandt, governorship, assaulted, balloting,
# Nearest to other: patricio, albrecht, tags, mountains, jarmusch, mircea, beatrix, rhetorician,
# Nearest to he: semantic, arms, outputting, attaining, cried, circumventing, liliuokalani, heracles,
# Nearest to first: snows, punishments, margherita, spee, algonquin, caribbean, monoxide, coldest,
# Nearest to i: picchi, fonseca, legions, gourd, differentials, furnishings, restaurants, yuri,
# Nearest to american: foundational, imprecise, inscriptions, dives, fencing, prisons, cocktails, singularities,
# Nearest to on: functionally, agglomeration, carte, philharmonic, fuji, dread, neutron, homeschool,
# Nearest to as: anaesthetics, mehrgarh, fever, mistress, scythians, renounced, canaan, dalglish,
# Nearest to two: says, grissom, unconnected, fraktion, verify, irregulars, uplink, finishes,
# Nearest to was: ground, acidity, tactile, sina, officio, chanced, dwell, baxter,
# Average loss at step  2000 :  114.24600673
# Average loss at step  4000 :  51.8504183397
# Average loss at step  6000 :  33.4221495357
# Average loss at step  8000 :  23.5755627038
# Average loss at step  10000 :  17.9962391995
# Nearest to the: a, his, and, lymphoma, deadly, gland, UNK, one,
# Nearest to more: major, declining, gland, spoken, zurich, load, surveillance, frequently,
# Nearest to they: psi, northwestern, afl, automobiles, aberdeen, alpina, sedgwick, uncommon,
# Nearest to world: remedy, join, receivers, samoa, films, atom, traders, military,
# Nearest to during: separatist, fable, agave, amounts, nine, phi, wins, amateur,
# Nearest to who: mamma, extract, and, rappers, phi, images, hermes, became,
# Nearest to of: and, in, on, nine, for, from, at, the,
# Nearest to other: mountains, warner, useful, ice, few, cl, vizier, edward,
# Nearest to he: also, lymphoma, it, semantic, phi, arms, gland, our,
# Nearest to first: coldest, solf, caribbean, action, punishments, bose, gb, convent,
# Nearest to i: enable, kingdom, imac, opens, lymphoma, two, questions, legions,
# Nearest to american: foundational, fencing, type, depression, complications, central, prisons, inscriptions,
# Nearest to on: in, and, of, for, var, to, ep, ridge,
# Nearest to as: in, phi, archie, describe, is, and, by, asceticism,
# Nearest to two: one, nine, var, phi, gland, zero, seven, ada,
# Nearest to was: is, ground, broke, sina, phi, gland, alpina, and,
# Average loss at step  12000 :  14.1490702939
# Average loss at step  14000 :  11.6941470004
# Average loss at step  16000 :  10.0241421275
# Average loss at step  18000 :  8.34953893703
# Average loss at step  20000 :  8.15561561179
# Nearest to the: a, his, one, their, its, agouti, and, this,
# Nearest to more: agouti, major, declining, spoken, elector, load, employed, concrete,
# Nearest to they: he, it, afl, psi, quadratic, northwestern, agouti, abm,
# Nearest to world: remedy, join, crocodile, receivers, agrippa, establishments, films, samoa,
# Nearest to during: fable, separatist, in, amounts, of, eddy, wins, agave,
# Nearest to who: and, he, it, mamma, extract, agouti, UNK, images,
# Nearest to of: in, and, for, agouti, from, nine, on, at,
# Nearest to other: mountains, rhetorician, albrecht, joab, francorum, ice, their, warner,
# Nearest to he: it, they, also, lymphoma, agouti, who, semantic, phi,
# Nearest to first: coldest, caribbean, convent, punishments, solf, shores, agouti, twain,
# Nearest to i: enable, asymmetric, legions, imac, questions, foreigners, lymphoma, bose,
# Nearest to american: and, complications, fencing, central, draws, absorbed, foundational, adaptations,
# Nearest to on: in, for, of, and, at, by, var, two,
# Nearest to as: and, is, describe, phi, by, for, agouti, in,
# Nearest to two: one, nine, five, three, six, four, zero, eight,
# Nearest to was: is, by, are, had, gland, phi, as, were,
# Average loss at step  22000 :  6.93192907095
# Average loss at step  24000 :  6.86189730346
# Average loss at step  26000 :  6.7066757561
# Average loss at step  28000 :  6.40021700644
# Average loss at step  30000 :  5.9120061245
# Nearest to the: its, their, his, a, this, circ, agave, agouti,
# Nearest to more: agouti, major, declining, elector, employed, normandy, spoken, abiogenesis,
# Nearest to they: he, it, there, not, mishnayot, psi, quadratic, afl,
# Nearest to world: join, ize, remedy, crocodile, establishments, conveys, agrippa, receivers,
# Nearest to during: in, fable, separatist, eddy, amounts, by, abet, of,
# Nearest to who: and, he, it, extract, which, mamma, approximants, agouti,
# Nearest to of: in, and, for, abet, eight, from, agouti, nine,
# Nearest to other: mountains, rhetorician, many, ice, albrecht, joab, francorum, their,
# Nearest to he: it, they, she, who, agouti, also, lymphoma, parks,
# Nearest to first: abet, coldest, convent, caribbean, punishments, amalthea, otimes, shores,
# Nearest to i: enable, abet, foreigners, asymmetric, two, legions, gourd, imac,
# Nearest to american: and, complications, fencing, central, adaptations, italian, absorbed, foundational,
# Nearest to on: in, for, at, of, and, abet, by, ep,
# Nearest to as: phi, and, by, is, agouti, archie, mishnayot, antipope,
# Nearest to two: four, three, one, six, eight, five, seven, nine,
# Nearest to was: is, had, were, by, mishnayot, has, gland, phi,
# Average loss at step  32000 :  5.95824400818
# Average loss at step  34000 :  5.72704813993
# Average loss at step  36000 :  5.81519289851
# Average loss at step  38000 :  5.48767654145
# Average loss at step  40000 :  5.2529589889
# Nearest to the: their, his, its, this, a, agave, agouti, circ,
# Nearest to more: agouti, declining, major, employed, normandy, elector, less, spoken,
# Nearest to they: he, it, there, not, who, we, bottleneck, quadratic,
# Nearest to world: ize, join, remedy, traders, establishments, crocodile, vegetarianism, conveys,
# Nearest to during: in, eddy, by, separatist, fable, amounts, abet, akita,
# Nearest to who: he, which, and, it, extract, they, approximants, anatolia,
# Nearest to of: in, abet, agouti, zero, for, eight, and, from,
# Nearest to other: many, mountains, albrecht, rhetorician, ice, ell, two, their,
# Nearest to he: it, they, she, who, agouti, there, also, lymphoma,
# Nearest to first: abet, coldest, convent, punishments, amalthea, caribbean, otimes, shores,
# Nearest to i: enable, abet, you, foreigners, differentials, UNK, asymmetric, questions,
# Nearest to american: central, italian, complications, fencing, adaptations, joined, absorbed, sint,
# Nearest to on: in, at, and, from, for, abet, mishnayot, ep,
# Nearest to as: phi, agouti, in, mishnayot, archie, amalthea, describe, and,
# Nearest to two: three, four, one, five, six, eight, seven, zero,
# Nearest to was: is, had, has, were, by, mishnayot, are, amalthea,
# Average loss at step  42000 :  5.35422186315
# Average loss at step  44000 :  5.22918218851
# Average loss at step  46000 :  5.28351279044
# Average loss at step  48000 :  5.22045635104
# Average loss at step  50000 :  5.00213464999
# Nearest to the: their, his, its, this, a, agouti, agave, circ,
# Nearest to more: agouti, less, most, declining, employed, very, elector, skunk,
# Nearest to they: he, there, it, we, not, you, who, mishnayot,
# Nearest to world: ize, join, remedy, traders, crocodile, establishments, vegetarianism, polka,
# Nearest to during: in, by, eddy, separatist, fable, abet, including, akita,
# Nearest to who: he, and, which, they, extract, it, anatolia, not,
# Nearest to of: in, abet, agouti, for, from, mishnayot, eight, aorta,
# Nearest to other: many, mountains, two, ell, albrecht, ice, rhetorician, mishnayot,
# Nearest to he: it, they, she, who, there, agouti, also, lymphoma,
# Nearest to first: abet, gundam, coldest, convent, amalthea, caribbean, traitors, punishments,
# Nearest to i: enable, you, abet, foreigners, UNK, he, lactose, questions,
# Nearest to american: complications, italian, central, adaptations, fencing, yankees, joined, sint,
# Nearest to on: in, at, two, mishnayot, abet, for, ep, from,
# Nearest to as: archie, phi, agouti, three, amalthea, seven, eight, mishnayot,
# Nearest to two: three, four, one, six, five, seven, eight, amalthea,
# Nearest to was: is, has, were, had, by, gland, mishnayot, be,
# Average loss at step  52000 :  5.01256266367
# Average loss at step  54000 :  5.19070379972
# Average loss at step  56000 :  5.05812052786
# Average loss at step  58000 :  5.05264110315
# Average loss at step  60000 :  4.93722898757
# Nearest to the: their, its, ursus, his, a, agouti, agave, microsite,
# Nearest to more: less, agouti, most, pulau, very, employed, usually, declining,
# Nearest to they: he, there, we, it, who, you, not, she,
# Nearest to world: ize, remedy, crocodile, traders, advancements, join, establishments, vegetarianism,
# Nearest to during: in, including, after, abet, eddy, from, awhile, through,
# Nearest to who: he, which, they, there, not, and, anatolia, extract,
# Nearest to of: and, in, abet, for, agouti, nine, michelob, ursus,
# Nearest to other: many, mountains, two, these, mishnayot, some, their, ice,
# Nearest to he: it, she, they, who, there, agouti, lymphoma, parks,
# Nearest to first: gundam, abet, second, amalthea, ursus, coldest, convent, otimes,
# Nearest to i: you, enable, abet, he, foreigners, questions, lactose, facilitating,
# Nearest to american: italian, complications, central, adaptations, joined, yankees, fencing, french,
# Nearest to on: in, at, from, abet, mishnayot, upon, for, following,
# Nearest to as: agouti, in, phi, mishnayot, amalthea, archie, canaris, is,
# Nearest to two: three, four, one, five, six, ursus, eight, seven,
# Nearest to was: is, had, has, were, by, gland, be, became,
# Average loss at step  62000 :  5.01932176173
# Average loss at step  64000 :  4.82873990071
# Average loss at step  66000 :  4.59601489353
# Average loss at step  68000 :  4.98587024581
# Average loss at step  70000 :  4.91329435694
# Nearest to the: their, its, his, a, ursus, this, thaler, agouti,
# Nearest to more: less, most, agouti, very, pulau, employed, declining, ursus,
# Nearest to they: he, there, we, you, it, not, who, these,
# Nearest to world: ize, crocodile, remedy, advancements, join, polka, establishments, traders,
# Nearest to during: in, after, including, by, through, abet, microcebus, akita,
# Nearest to who: he, which, they, and, extract, there, approximants, anatolia,
# Nearest to of: abet, and, agouti, microcebus, michelob, for, in, ursus,
# Nearest to other: many, these, some, callithrix, mountains, ell, masking, mishnayot,
# Nearest to he: it, she, they, who, there, agouti, phi, i,
# Nearest to first: gundam, abet, second, microcebus, amalthea, ursus, agouti, unassigned,
# Nearest to i: you, enable, abet, he, foreigners, UNK, questions, ii,
# Nearest to american: italian, complications, central, joined, adaptations, french, journeyed, yankees,
# Nearest to on: in, upon, at, mishnayot, abet, from, following, ep,
# Nearest to as: antipope, archie, mishnayot, agouti, canaris, phi, in, amalthea,
# Nearest to two: three, four, six, five, one, eight, seven, ursus,
# Nearest to was: is, had, were, has, by, became, gland, be,
# Average loss at step  72000 :  4.763430565
# Average loss at step  74000 :  4.83145785356
# Average loss at step  76000 :  4.720074561
# Average loss at step  78000 :  4.7974904651
# Average loss at step  80000 :  4.80203841352
# Nearest to the: their, a, cebus, his, ursus, its, thaler, agave,
# Nearest to more: less, most, very, agouti, pulau, nostalgia, employed, smaller,
# Nearest to they: he, there, we, you, it, who, not, she,
# Nearest to world: crocodile, remedy, advancements, ize, polka, join, vegetarianism, establishments,
# Nearest to during: in, after, through, including, by, abet, microcebus, of,
# Nearest to who: he, they, which, and, there, approximants, anatolia, extract,
# Nearest to of: in, abet, agouti, nine, microcebus, including, mishnayot, michelob,
# Nearest to other: many, these, some, mountains, callithrix, various, two, including,
# Nearest to he: it, she, they, who, there, agouti, phi, parks,
# Nearest to first: second, gundam, abet, microcebus, amalthea, ursus, coldest, agouti,
# Nearest to i: you, enable, abet, foreigners, UNK, he, we, ii,
# Nearest to american: italian, complications, french, joined, central, adaptations, journeyed, ursus,
# Nearest to on: in, at, upon, through, from, mishnayot, clodius, ep,
# Nearest to as: mishnayot, canaris, agouti, seven, overline, phi, thz, archie,
# Nearest to two: three, four, six, five, seven, one, eight, ursus,
# Nearest to was: is, had, were, has, by, became, be, been,
# Average loss at step  82000 :  4.77015306902
# Average loss at step  84000 :  4.75913242507
# Average loss at step  86000 :  4.76940216362
# Average loss at step  88000 :  4.73219079876
# Average loss at step  90000 :  4.73636309922
# Nearest to the: their, its, a, this, his, cebus, ursus, agouti,
# Nearest to more: less, most, very, agouti, pulau, nostalgia, employed, dreidel,
# Nearest to they: he, we, there, you, it, who, not, she,
# Nearest to world: crocodile, remedy, advancements, ize, polka, vegetarianism, join, traders,
# Nearest to during: in, after, including, through, from, abet, by, at,
# Nearest to who: he, which, they, and, jati, there, often, extract,
# Nearest to of: abet, in, including, agouti, michelob, microcebus, vma, eight,
# Nearest to other: many, these, some, two, including, various, mountains, masking,
# Nearest to he: it, she, they, who, there, agouti, but, phi,
# Nearest to first: second, gundam, microcebus, abet, next, last, amalthea, coldest,
# Nearest to i: you, UNK, enable, abet, ii, he, we, foreigners,
# Nearest to american: italian, complications, french, adaptations, joined, british, german, ursus,
# Nearest to on: in, upon, at, from, through, clodius, following, mishnayot,
# Nearest to as: agouti, overline, canaris, by, phi, mishnayot, archie, in,
# Nearest to two: three, four, five, one, six, seven, eight, ursus,
# Nearest to was: is, had, has, were, became, by, be, been,
# Average loss at step  92000 :  4.66943973565
# Average loss at step  94000 :  4.73256876087
# Average loss at step  96000 :  4.70035339904
# Average loss at step  98000 :  4.59465997612
# Average loss at step  100000 :  4.69708482265
# Nearest to the: their, its, ursus, a, this, thaler, his, cebus,
# Nearest to more: less, most, very, agouti, pulau, smaller, nostalgia, normandy,
# Nearest to they: he, there, we, you, it, she, not, these,
# Nearest to world: ize, crocodile, remedy, polka, advancements, join, vegetarianism, winston,
# Nearest to during: in, after, through, including, by, abet, at, from,
# Nearest to who: he, they, which, jati, anatolia, and, often, caches,
# Nearest to of: in, abet, including, agouti, michelob, and, microcebus, ursus,
# Nearest to other: many, various, these, including, some, tub, different, two,
# Nearest to he: it, she, they, there, who, agouti, but, phi,
# Nearest to first: second, gundam, microcebus, abet, last, next, coldest, amalthea,
# Nearest to i: you, abet, enable, ii, we, he, foreigners, cru,
# Nearest to american: italian, complications, french, british, adaptations, english, german, destry,
# Nearest to on: in, upon, at, through, from, clodius, following, mishnayot,
# Nearest to as: mishnayot, phi, agouti, ursus, canaris, thz, by, saya,
# Nearest to two: three, four, five, one, six, seven, eight, ursus,
# Nearest to was: is, has, had, were, became, by, be, gland,

# %%
normalized_embeddings
# Out:
# <tf.Tensor 'truediv:0' shape=(50000, 128) dtype=float32>

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# Step 6: Visualize the embeddings.

def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    
    plt.savefig(filename)

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 1000
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
